# %%
"""
Genera data sintética de productos para la confitería Dulcino.
- Aplica TODAS las validaciones de la historia de usuario.
- Guarda en datos_sinteticos/products.csv (append seguro).
- Puede generar en batch (sintético) y también aceptar un registro manual (modo demo).
"""

from __future__ import annotations
import os, csv, random, string
from dataclasses import dataclass, asdict
from datetime import datetime
from typing import List

# -------------------------------
# Configuración / constantes
# -------------------------------
DATA_DIR = os.path.join("datos_sinteticos")
CSV_PATH = os.path.join(DATA_DIR, "products.csv")

CATEGORIAS_VALIDAS = ["Chocolates", "Caramelos", "Mashmelos", 
                      "Galletas", "Salados", "Gomas de mascar"]

os.makedirs(DATA_DIR, exist_ok=True)
if not os.path.exists(CSV_PATH):
    with open(CSV_PATH, "w", newline="", encoding="utf-8") as f:
        writer = csv.writer(f)
        writer.writerow(["Nombre", "Precio", "Categorías", "En venta", "FechaRegistro"])

# -------------------------------
# Modelo de datos
# -------------------------------
@dataclass
class Producto:
    nombre: str
    precio: float
    categorias: List[str]
    en_venta: bool
    
    def validar(self) -> List[str]:
        errores = []
        # Nombre
        if len(self.nombre.strip()) == 0 or len(self.nombre) > 20:
            errores.append("El nombre debe tener máximo 20 caracteres y no estar vacío.")
        # Precio
        if not (0 < self.precio < 999):
            errores.append("El precio debe ser mayor a 0 y menor a 999.")
        # Categorías
        if len(self.categorias) == 0:
            errores.append("Debe seleccionar al menos una categoría.")
        for c in self.categorias:
            if c not in CATEGORIAS_VALIDAS:
                errores.append(f"Categoría no válida: {c}")
        return errores

    def guardar(self):
        errores = self.validar()
        if errores:
            raise ValueError("Errores de validación: " + "; ".join(errores))
        with open(CSV_PATH, "a", newline="", encoding="utf-8") as f:
            writer = csv.writer(f)
            writer.writerow([
                self.nombre, 
                self.precio, 
                ";".join(self.categorias), 
                "Sí" if self.en_venta else "No", 
                datetime.now().isoformat()
            ])

# -------------------------------
# Funciones auxiliares
# -------------------------------
def generar_nombre_aleatorio():
    return "Prod" + ''.join(random.choices(string.ascii_uppercase, k=3))

def generar_producto_aleatorio() -> Producto:
    nombre = generar_nombre_aleatorio()
    precio = round(random.uniform(1, 998), 2)
    categorias = random.sample(CATEGORIAS_VALIDAS, random.randint(1, 3))
    en_venta = random.choice([True, False])
    return Producto(nombre, precio, categorias, en_venta)

def generar_batch(n: int = 10):
    for _ in range(n):
        p = generar_producto_aleatorio()
        try:
            p.guardar()
            print(f"✅ Producto agregado: {p}")
        except Exception as e:
            print(f"❌ Error: {e}")

# -------------------------------
# Modo demo (manual)
# -------------------------------
def registrar_manual():
    nombre = input("Ingrese nombre del producto: ")
    try:
        precio = float(input("Ingrese precio del producto (S/.): "))
    except:
        print("⚠️ Por favor verifique el campo del precio.")
        return
    categorias = input("Ingrese categorías separadas por coma: ").split(",")
    categorias = [c.strip() for c in categorias]
    en_venta = input("¿Está en venta? (s/n): ").lower() == "s"
    producto = Producto(nombre, precio, categorias, en_venta)
    try:
        producto.guardar()
        print("✅ Felicidades su producto se agregó.")
    except Exception as e:
        print("❌ Lo sentimos no pudo crear este producto.")
        print(e)

# -------------------------------
# Ejecución de ejemplo
# -------------------------------
if __name__ == "__main__":
    print("Generando lote de prueba (5 productos)...")
    generar_batch(300)
    print("\nAhora puede registrar manualmente:")
    # registrar_manual()
# Out:
# Generando lote de prueba (5 productos)...
# ✅ Producto agregado: Producto(nombre='ProdRZF', precio=933.94, categorias=['Salados', 'Galletas', 'Gomas de mascar'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdWAO', precio=35.03, categorias=['Mashmelos', 'Gomas de mascar', 'Caramelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdLEU', precio=400.29, categorias=['Caramelos', 'Gomas de mascar', 'Galletas'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdHWT', precio=815.25, categorias=['Caramelos', 'Gomas de mascar'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdLAP', precio=212.08, categorias=['Chocolates', 'Gomas de mascar'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdOUM', precio=720.96, categorias=['Gomas de mascar'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdYSV', precio=54.27, categorias=['Caramelos', 'Chocolates'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdWTH', precio=669.23, categorias=['Chocolates', 'Salados', 'Galletas'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdKDF', precio=499.75, categorias=['Mashmelos', 'Caramelos', 'Salados'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdTGT', precio=360.87, categorias=['Gomas de mascar', 'Mashmelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdNIZ', precio=297.73, categorias=['Caramelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdFTN', precio=434.55, categorias=['Caramelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdGQF', precio=249.49, categorias=['Caramelos', 'Galletas'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdHXD', precio=930.91, categorias=['Mashmelos', 'Galletas'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdLBB', precio=944.26, categorias=['Caramelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdLGQ', precio=357.24, categorias=['Gomas de mascar'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdOEY', precio=936.99, categorias=['Gomas de mascar', 'Salados'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdZZN', precio=214.68, categorias=['Mashmelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdXOT', precio=654.23, categorias=['Salados'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdAEK', precio=119.84, categorias=['Gomas de mascar', 'Salados', 'Mashmelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdZTM', precio=241.13, categorias=['Salados', 'Galletas', 'Caramelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdUVL', precio=982.8, categorias=['Mashmelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdARR', precio=822.14, categorias=['Gomas de mascar', 'Caramelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdVAY', precio=712.19, categorias=['Salados'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdSFC', precio=657.9, categorias=['Salados'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdXCP', precio=320.62, categorias=['Chocolates', 'Caramelos', 'Galletas'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdEPL', precio=678.12, categorias=['Gomas de mascar', 'Mashmelos', 'Salados'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdFLX', precio=811.73, categorias=['Chocolates', 'Mashmelos', 'Gomas de mascar'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdJYM', precio=467.4, categorias=['Mashmelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdDKN', precio=732.16, categorias=['Galletas', 'Caramelos', 'Salados'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdQMC', precio=59.71, categorias=['Gomas de mascar', 'Mashmelos', 'Chocolates'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdPMJ', precio=849.03, categorias=['Salados', 'Chocolates', 'Gomas de mascar'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdADV', precio=714.89, categorias=['Chocolates', 'Caramelos', 'Mashmelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdTRL', precio=510.9, categorias=['Salados'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdDIO', precio=369.21, categorias=['Galletas', 'Salados'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdFNK', precio=304.74, categorias=['Chocolates', 'Gomas de mascar'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdQCP', precio=136.98, categorias=['Salados'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdITA', precio=199.29, categorias=['Gomas de mascar'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdTZI', precio=828.18, categorias=['Chocolates'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdSVX', precio=514.9, categorias=['Caramelos', 'Mashmelos', 'Chocolates'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdZAV', precio=2.05, categorias=['Salados'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdTIS', precio=504.86, categorias=['Chocolates'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdKJS', precio=752.92, categorias=['Salados', 'Mashmelos', 'Gomas de mascar'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdWXC', precio=975.02, categorias=['Gomas de mascar', 'Chocolates'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdBNP', precio=239.58, categorias=['Caramelos', 'Salados'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdIPH', precio=145.97, categorias=['Chocolates'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdQCD', precio=513.7, categorias=['Chocolates', 'Salados', 'Mashmelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdDRK', precio=674.76, categorias=['Mashmelos', 'Galletas'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdQYO', precio=861.73, categorias=['Chocolates', 'Galletas', 'Mashmelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdZUA', precio=801.21, categorias=['Chocolates', 'Mashmelos', 'Gomas de mascar'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdMLS', precio=931.14, categorias=['Galletas', 'Gomas de mascar', 'Chocolates'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdXFP', precio=125.43, categorias=['Chocolates', 'Caramelos', 'Mashmelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdNWV', precio=576.44, categorias=['Mashmelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdWNA', precio=911.91, categorias=['Galletas'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdZED', precio=133.83, categorias=['Mashmelos', 'Caramelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdPGG', precio=80.74, categorias=['Gomas de mascar', 'Chocolates', 'Mashmelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdAAO', precio=694.13, categorias=['Gomas de mascar', 'Chocolates', 'Mashmelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdLUK', precio=763.73, categorias=['Chocolates', 'Gomas de mascar', 'Caramelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdWVH', precio=105.05, categorias=['Salados', 'Mashmelos', 'Galletas'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdOFF', precio=804.0, categorias=['Galletas', 'Caramelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdSCJ', precio=823.13, categorias=['Caramelos', 'Mashmelos', 'Galletas'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdBMO', precio=436.96, categorias=['Gomas de mascar'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdLWT', precio=298.59, categorias=['Gomas de mascar', 'Chocolates'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdWBR', precio=879.81, categorias=['Chocolates', 'Salados'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdRWH', precio=76.57, categorias=['Mashmelos', 'Caramelos', 'Gomas de mascar'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdIAZ', precio=742.39, categorias=['Salados', 'Gomas de mascar'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdLCX', precio=28.76, categorias=['Mashmelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdFYH', precio=3.04, categorias=['Chocolates', 'Salados'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdNFD', precio=217.31, categorias=['Chocolates', 'Caramelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdFPL', precio=41.1, categorias=['Chocolates', 'Salados', 'Mashmelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdMDM', precio=543.01, categorias=['Caramelos', 'Gomas de mascar'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdUGH', precio=566.24, categorias=['Galletas', 'Gomas de mascar'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdUSQ', precio=501.38, categorias=['Caramelos', 'Salados', 'Galletas'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdDCF', precio=794.18, categorias=['Caramelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdAEN', precio=982.94, categorias=['Chocolates', 'Caramelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdLSE', precio=557.42, categorias=['Salados', 'Galletas', 'Caramelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdGCD', precio=120.62, categorias=['Mashmelos', 'Caramelos', 'Chocolates'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdYBE', precio=576.35, categorias=['Chocolates', 'Galletas'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdTVA', precio=898.29, categorias=['Salados'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdEUO', precio=997.71, categorias=['Caramelos', 'Galletas'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdFIN', precio=957.69, categorias=['Gomas de mascar', 'Chocolates'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdJBT', precio=718.08, categorias=['Mashmelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdQFI', precio=56.11, categorias=['Galletas', 'Caramelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdBRL', precio=852.47, categorias=['Caramelos', 'Chocolates'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdUMM', precio=461.95, categorias=['Salados'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdHUP', precio=276.6, categorias=['Mashmelos', 'Gomas de mascar', 'Salados'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdLPG', precio=984.84, categorias=['Salados'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdSTZ', precio=225.32, categorias=['Chocolates'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdIDE', precio=939.19, categorias=['Mashmelos', 'Caramelos', 'Galletas'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdPFC', precio=531.11, categorias=['Caramelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdEJY', precio=824.03, categorias=['Chocolates'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdNAW', precio=351.13, categorias=['Mashmelos', 'Gomas de mascar', 'Caramelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdSKF', precio=124.79, categorias=['Galletas', 'Mashmelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdCFH', precio=74.23, categorias=['Mashmelos', 'Caramelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdSOZ', precio=395.02, categorias=['Caramelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdHZD', precio=393.09, categorias=['Galletas', 'Caramelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdZYG', precio=716.81, categorias=['Salados', 'Mashmelos', 'Caramelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdQWC', precio=966.66, categorias=['Mashmelos', 'Caramelos', 'Galletas'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdIJG', precio=778.12, categorias=['Gomas de mascar'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdIAK', precio=46.04, categorias=['Gomas de mascar', 'Caramelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdXWT', precio=872.37, categorias=['Caramelos', 'Galletas'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdTTV', precio=58.04, categorias=['Chocolates'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdCPL', precio=456.94, categorias=['Salados'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdITT', precio=470.46, categorias=['Galletas', 'Salados', 'Mashmelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdHQR', precio=735.16, categorias=['Caramelos', 'Mashmelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdEDU', precio=439.53, categorias=['Galletas', 'Salados', 'Caramelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdBJQ', precio=191.71, categorias=['Galletas', 'Chocolates', 'Gomas de mascar'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdTZN', precio=14.31, categorias=['Caramelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdQDQ', precio=586.31, categorias=['Caramelos', 'Salados', 'Gomas de mascar'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdNWB', precio=409.87, categorias=['Chocolates'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdEKH', precio=764.93, categorias=['Galletas', 'Chocolates'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdITU', precio=756.16, categorias=['Salados'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdQEJ', precio=472.11, categorias=['Mashmelos', 'Caramelos', 'Gomas de mascar'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdIYP', precio=594.32, categorias=['Gomas de mascar', 'Mashmelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdJWA', precio=665.47, categorias=['Galletas', 'Caramelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdTIP', precio=786.38, categorias=['Caramelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdVFM', precio=786.3, categorias=['Chocolates', 'Galletas'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdIRN', precio=861.17, categorias=['Mashmelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdDQU', precio=601.41, categorias=['Gomas de mascar'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdYGI', precio=59.4, categorias=['Salados'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdZET', precio=878.14, categorias=['Galletas', 'Caramelos', 'Chocolates'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdGPM', precio=54.86, categorias=['Gomas de mascar'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdXUO', precio=868.4, categorias=['Gomas de mascar', 'Mashmelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdEZO', precio=646.28, categorias=['Chocolates'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdALC', precio=313.71, categorias=['Galletas'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdIWI', precio=275.35, categorias=['Chocolates', 'Gomas de mascar'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdNVO', precio=606.06, categorias=['Caramelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdDZW', precio=937.26, categorias=['Galletas'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdMRI', precio=269.0, categorias=['Gomas de mascar', 'Caramelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdCPW', precio=692.64, categorias=['Galletas', 'Gomas de mascar', 'Chocolates'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdVHW', precio=55.86, categorias=['Caramelos', 'Gomas de mascar'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdOKA', precio=476.83, categorias=['Galletas', 'Gomas de mascar', 'Chocolates'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdOOD', precio=682.29, categorias=['Mashmelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdSWQ', precio=164.2, categorias=['Caramelos', 'Mashmelos', 'Gomas de mascar'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdMTM', precio=209.42, categorias=['Salados', 'Caramelos', 'Gomas de mascar'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdXXN', precio=651.37, categorias=['Gomas de mascar'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdCIS', precio=612.31, categorias=['Caramelos', 'Salados', 'Chocolates'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdVVI', precio=430.48, categorias=['Galletas'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdIBP', precio=107.53, categorias=['Gomas de mascar', 'Mashmelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdPTE', precio=527.62, categorias=['Chocolates', 'Mashmelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdZCV', precio=727.25, categorias=['Gomas de mascar', 'Mashmelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdLXS', precio=449.88, categorias=['Salados', 'Galletas', 'Mashmelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdPAT', precio=959.96, categorias=['Gomas de mascar', 'Mashmelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdQSG', precio=39.49, categorias=['Gomas de mascar', 'Mashmelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdNKL', precio=358.49, categorias=['Salados'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdJEA', precio=767.13, categorias=['Salados', 'Galletas'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdXLJ', precio=8.91, categorias=['Caramelos', 'Galletas', 'Salados'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdRIR', precio=731.51, categorias=['Salados', 'Gomas de mascar'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdOBS', precio=464.24, categorias=['Caramelos', 'Gomas de mascar'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdOBQ', precio=620.12, categorias=['Mashmelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdTRL', precio=252.46, categorias=['Galletas', 'Mashmelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdMRR', precio=852.74, categorias=['Chocolates', 'Mashmelos', 'Gomas de mascar'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdKAD', precio=225.24, categorias=['Gomas de mascar', 'Galletas'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdBKX', precio=121.58, categorias=['Caramelos', 'Chocolates'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdDPM', precio=474.92, categorias=['Galletas', 'Gomas de mascar'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdPQG', precio=674.23, categorias=['Salados'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdKZV', precio=983.7, categorias=['Galletas', 'Chocolates'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdGOQ', precio=317.79, categorias=['Mashmelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdRDB', precio=377.24, categorias=['Chocolates', 'Gomas de mascar'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdLBL', precio=223.5, categorias=['Chocolates'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdTDY', precio=605.12, categorias=['Gomas de mascar', 'Salados', 'Caramelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdQJQ', precio=904.74, categorias=['Mashmelos', 'Galletas', 'Salados'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdTDJ', precio=690.43, categorias=['Galletas', 'Salados', 'Gomas de mascar'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdHAK', precio=497.4, categorias=['Salados', 'Gomas de mascar', 'Galletas'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdDYM', precio=178.24, categorias=['Salados', 'Caramelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdSSE', precio=548.02, categorias=['Gomas de mascar'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdDKN', precio=595.15, categorias=['Chocolates', 'Mashmelos', 'Gomas de mascar'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdMHH', precio=671.9, categorias=['Mashmelos', 'Gomas de mascar'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdFXS', precio=582.95, categorias=['Galletas', 'Salados', 'Caramelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdDOW', precio=40.3, categorias=['Caramelos', 'Gomas de mascar'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdJSX', precio=486.72, categorias=['Mashmelos', 'Chocolates', 'Galletas'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdPNQ', precio=11.47, categorias=['Caramelos', 'Galletas', 'Salados'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdMPK', precio=735.86, categorias=['Mashmelos', 'Salados', 'Caramelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdRIZ', precio=780.87, categorias=['Gomas de mascar', 'Chocolates'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdWFB', precio=980.56, categorias=['Salados'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdJEB', precio=390.96, categorias=['Gomas de mascar', 'Caramelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdXZE', precio=227.67, categorias=['Galletas'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdQHE', precio=819.37, categorias=['Gomas de mascar', 'Mashmelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdPLS', precio=368.62, categorias=['Caramelos', 'Galletas'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdYMX', precio=769.82, categorias=['Galletas'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdCON', precio=262.6, categorias=['Chocolates'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdRIV', precio=979.39, categorias=['Chocolates'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdMLB', precio=312.83, categorias=['Salados', 'Gomas de mascar'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdGNL', precio=67.88, categorias=['Salados', 'Chocolates'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdPED', precio=402.95, categorias=['Mashmelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdEMY', precio=888.32, categorias=['Galletas', 'Gomas de mascar'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdZJO', precio=950.6, categorias=['Caramelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdPOE', precio=165.37, categorias=['Galletas', 'Mashmelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdRPL', precio=768.31, categorias=['Chocolates', 'Mashmelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdLEW', precio=746.78, categorias=['Salados', 'Caramelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdBEZ', precio=848.83, categorias=['Caramelos', 'Salados'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdGTE', precio=366.11, categorias=['Salados', 'Gomas de mascar', 'Galletas'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdZUU', precio=40.72, categorias=['Mashmelos', 'Salados', 'Galletas'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdESM', precio=162.32, categorias=['Salados'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdGUS', precio=389.17, categorias=['Gomas de mascar', 'Mashmelos', 'Chocolates'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdGFJ', precio=835.15, categorias=['Salados', 'Caramelos', 'Gomas de mascar'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdMPU', precio=100.51, categorias=['Caramelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdRLJ', precio=63.71, categorias=['Caramelos', 'Salados'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdZIR', precio=150.83, categorias=['Chocolates', 'Galletas'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdEFL', precio=815.91, categorias=['Caramelos', 'Salados'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdWIZ', precio=331.74, categorias=['Gomas de mascar'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdJTI', precio=349.58, categorias=['Galletas', 'Mashmelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdXSZ', precio=777.19, categorias=['Galletas', 'Salados', 'Mashmelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdLDE', precio=994.59, categorias=['Salados', 'Chocolates'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdQAO', precio=220.49, categorias=['Chocolates'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdYWG', precio=152.68, categorias=['Mashmelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdIJN', precio=486.15, categorias=['Mashmelos', 'Chocolates', 'Gomas de mascar'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdQUT', precio=382.91, categorias=['Mashmelos', 'Chocolates'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdWDB', precio=888.91, categorias=['Caramelos', 'Gomas de mascar'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdZNJ', precio=927.66, categorias=['Chocolates'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdEPU', precio=635.42, categorias=['Mashmelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdNTF', precio=223.36, categorias=['Chocolates', 'Salados'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdYKS', precio=581.99, categorias=['Chocolates', 'Galletas'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdDWZ', precio=21.87, categorias=['Salados', 'Gomas de mascar', 'Chocolates'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdFBQ', precio=299.84, categorias=['Gomas de mascar', 'Salados', 'Caramelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdWRI', precio=680.02, categorias=['Chocolates', 'Salados', 'Galletas'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdCFY', precio=725.94, categorias=['Mashmelos', 'Caramelos', 'Salados'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdYRL', precio=763.88, categorias=['Galletas'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdACV', precio=302.87, categorias=['Salados', 'Galletas'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdSGQ', precio=638.82, categorias=['Gomas de mascar', 'Galletas', 'Salados'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdQHT', precio=188.77, categorias=['Caramelos', 'Salados', 'Galletas'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdHTS', precio=556.37, categorias=['Mashmelos', 'Chocolates', 'Caramelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdDOE', precio=878.96, categorias=['Galletas', 'Gomas de mascar', 'Mashmelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdLZV', precio=576.07, categorias=['Gomas de mascar', 'Salados', 'Mashmelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdCOJ', precio=914.93, categorias=['Mashmelos', 'Chocolates'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdLXD', precio=748.57, categorias=['Salados', 'Galletas'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdXTY', precio=870.78, categorias=['Gomas de mascar'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdUYY', precio=290.52, categorias=['Salados'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdRML', precio=963.1, categorias=['Salados'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdFBI', precio=548.37, categorias=['Chocolates', 'Mashmelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdQGK', precio=104.74, categorias=['Chocolates'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdAMF', precio=602.23, categorias=['Galletas', 'Gomas de mascar', 'Caramelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdMKL', precio=228.75, categorias=['Gomas de mascar'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdAMR', precio=416.72, categorias=['Gomas de mascar', 'Mashmelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdVJI', precio=526.3, categorias=['Gomas de mascar', 'Chocolates'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdURH', precio=538.62, categorias=['Mashmelos', 'Caramelos', 'Gomas de mascar'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdHBF', precio=390.33, categorias=['Mashmelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdERB', precio=572.77, categorias=['Galletas', 'Gomas de mascar', 'Mashmelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdFMM', precio=84.62, categorias=['Galletas'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdHXZ', precio=176.29, categorias=['Galletas', 'Mashmelos', 'Salados'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdFLV', precio=858.32, categorias=['Caramelos', 'Gomas de mascar'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdWWH', precio=993.57, categorias=['Mashmelos', 'Salados'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdGWZ', precio=953.37, categorias=['Mashmelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdLLN', precio=861.15, categorias=['Caramelos', 'Mashmelos', 'Gomas de mascar'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdNBU', precio=874.54, categorias=['Galletas'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdNWW', precio=216.39, categorias=['Galletas'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdDXG', precio=810.16, categorias=['Caramelos', 'Chocolates'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdMTU', precio=95.51, categorias=['Galletas'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdNIJ', precio=396.25, categorias=['Mashmelos', 'Gomas de mascar'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdXTE', precio=172.91, categorias=['Salados'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdSWR', precio=359.03, categorias=['Galletas', 'Caramelos', 'Gomas de mascar'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdFUJ', precio=54.8, categorias=['Salados', 'Chocolates', 'Mashmelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdKIR', precio=943.81, categorias=['Caramelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdVLF', precio=617.74, categorias=['Salados', 'Chocolates', 'Caramelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdNJY', precio=756.76, categorias=['Mashmelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdDGP', precio=247.27, categorias=['Gomas de mascar', 'Mashmelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdCYH', precio=515.7, categorias=['Mashmelos', 'Gomas de mascar'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdMDY', precio=230.61, categorias=['Chocolates', 'Caramelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdQKN', precio=661.41, categorias=['Salados'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdQWY', precio=279.34, categorias=['Gomas de mascar', 'Salados'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdZWK', precio=307.9, categorias=['Gomas de mascar', 'Caramelos', 'Salados'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdXSC', precio=964.95, categorias=['Caramelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdXLV', precio=187.61, categorias=['Galletas', 'Chocolates', 'Gomas de mascar'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdSOL', precio=661.52, categorias=['Chocolates'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdGCA', precio=47.34, categorias=['Chocolates', 'Gomas de mascar'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdBOQ', precio=704.24, categorias=['Salados'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdYAH', precio=634.59, categorias=['Galletas', 'Chocolates'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdJXP', precio=400.44, categorias=['Galletas', 'Caramelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdBOP', precio=699.43, categorias=['Galletas'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdSFD', precio=820.37, categorias=['Caramelos', 'Chocolates', 'Salados'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdKHE', precio=143.32, categorias=['Caramelos', 'Gomas de mascar', 'Salados'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdLBY', precio=92.14, categorias=['Salados', 'Mashmelos', 'Galletas'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdHNN', precio=98.96, categorias=['Gomas de mascar', 'Galletas'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdUXU', precio=120.81, categorias=['Salados', 'Mashmelos', 'Caramelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdKWA', precio=594.42, categorias=['Galletas', 'Mashmelos', 'Chocolates'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdBMR', precio=704.92, categorias=['Caramelos', 'Mashmelos', 'Salados'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdAWA', precio=59.28, categorias=['Mashmelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdWVU', precio=180.71, categorias=['Galletas'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdHSE', precio=615.29, categorias=['Caramelos', 'Mashmelos', 'Gomas de mascar'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdFMW', precio=494.23, categorias=['Gomas de mascar', 'Mashmelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdAKW', precio=477.09, categorias=['Mashmelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdJVL', precio=305.87, categorias=['Chocolates'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdAVS', precio=42.74, categorias=['Chocolates'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdPII', precio=691.03, categorias=['Galletas', 'Salados', 'Chocolates'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdNUB', precio=55.8, categorias=['Salados', 'Mashmelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdUKV', precio=247.92, categorias=['Chocolates'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdOFG', precio=322.26, categorias=['Salados'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdIUG', precio=940.63, categorias=['Gomas de mascar'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdYFJ', precio=634.16, categorias=['Gomas de mascar', 'Chocolates'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdZOR', precio=198.64, categorias=['Chocolates', 'Salados'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdNTI', precio=865.12, categorias=['Chocolates'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdCYL', precio=169.23, categorias=['Galletas', 'Gomas de mascar', 'Caramelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdMOK', precio=439.28, categorias=['Chocolates', 'Salados', 'Mashmelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdYHU', precio=407.39, categorias=['Mashmelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdCVD', precio=337.93, categorias=['Salados', 'Chocolates'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdHLN', precio=940.17, categorias=['Galletas', 'Chocolates'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdAJP', precio=622.52, categorias=['Salados', 'Gomas de mascar'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdZOA', precio=783.84, categorias=['Chocolates', 'Caramelos', 'Mashmelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdOVB', precio=43.98, categorias=['Caramelos', 'Galletas', 'Chocolates'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdUZH', precio=204.37, categorias=['Mashmelos'], en_venta=True)
#
# Ahora puede registrar manualmente:
