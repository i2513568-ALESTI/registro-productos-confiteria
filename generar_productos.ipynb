# %%
"""
Genera data sintética de productos para la confitería Dulcino.
- Aplica TODAS las validaciones de la historia de usuario.
- Guarda en datos_sinteticos/products.csv (append seguro).
- Puede generar en batch (sintético) y también aceptar un registro manual (modo demo).
"""

from __future__ import annotations
import os, csv, random, string
from dataclasses import dataclass, asdict
from datetime import datetime
from typing import List

# -------------------------------
# Configuración / constantes
# -------------------------------
DATA_DIR = os.path.join("datos_sinteticos")
CSV_PATH = os.path.join(DATA_DIR, "products.csv")

CATEGORIAS_VALIDAS = ["Chocolates", "Caramelos", "Mashmelos", 
                      "Galletas", "Salados", "Gomas de mascar"]

os.makedirs(DATA_DIR, exist_ok=True)
if not os.path.exists(CSV_PATH):
    with open(CSV_PATH, "w", newline="", encoding="utf-8") as f:
        writer = csv.writer(f)
        writer.writerow(["Nombre", "Precio", "Categorías", "En venta", "FechaRegistro"])

# -------------------------------
# Modelo de datos
# -------------------------------
@dataclass
class Producto:
    nombre: str
    precio: float
    categorias: List[str]
    en_venta: bool
    
    def validar(self) -> List[str]:
        errores = []
        # Nombre
        if len(self.nombre.strip()) == 0 or len(self.nombre) > 20:
            errores.append("El nombre debe tener máximo 20 caracteres y no estar vacío.")
        # Precio
        if not (0 < self.precio < 999):
            errores.append("El precio debe ser mayor a 0 y menor a 999.")
        # Categorías
        if len(self.categorias) == 0:
            errores.append("Debe seleccionar al menos una categoría.")
        for c in self.categorias:
            if c not in CATEGORIAS_VALIDAS:
                errores.append(f"Categoría no válida: {c}")
        return errores

    def guardar(self):
        errores = self.validar()
        if errores:
            raise ValueError("Errores de validación: " + "; ".join(errores))
        with open(CSV_PATH, "a", newline="", encoding="utf-8") as f:
            writer = csv.writer(f)
            writer.writerow([
                self.nombre, 
                self.precio, 
                ";".join(self.categorias), 
                "Sí" if self.en_venta else "No", 
                datetime.now().isoformat()
            ])

# -------------------------------
# Funciones auxiliares
# -------------------------------
def generar_nombre_aleatorio():
    return "Prod" + ''.join(random.choices(string.ascii_uppercase, k=3))

def generar_producto_aleatorio() -> Producto:
    nombre = generar_nombre_aleatorio()
    precio = round(random.uniform(1, 998), 2)
    categorias = random.sample(CATEGORIAS_VALIDAS, random.randint(1, 3))
    en_venta = random.choice([True, False])
    return Producto(nombre, precio, categorias, en_venta)

def generar_batch(n: int = 10):
    for _ in range(n):
        p = generar_producto_aleatorio()
        try:
            p.guardar()
            print(f"✅ Producto agregado: {p}")
        except Exception as e:
            print(f"❌ Error: {e}")

# -------------------------------
# Modo demo (manual)
# -------------------------------
def registrar_manual():
    nombre = input("Ingrese nombre del producto: ")
    try:
        precio = float(input("Ingrese precio del producto (S/.): "))
    except:
        print("⚠️ Por favor verifique el campo del precio.")
        return
    categorias = input("Ingrese categorías separadas por coma: ").split(",")
    categorias = [c.strip() for c in categorias]
    en_venta = input("¿Está en venta? (s/n): ").lower() == "s"
    producto = Producto(nombre, precio, categorias, en_venta)
    try:
        producto.guardar()
        print("✅ Felicidades su producto se agregó.")
    except Exception as e:
        print("❌ Lo sentimos no pudo crear este producto.")
        print(e)

# -------------------------------
# Ejecución de ejemplo
# -------------------------------
if __name__ == "__main__":
    print("Generando lote de prueba (5 productos)...")
    generar_batch(300)
    print("\nAhora puede registrar manualmente:")
    # registrar_manual()
# Out:
# Generando lote de prueba (5 productos)...
# ✅ Producto agregado: Producto(nombre='ProdWZP', precio=208.92, categorias=['Salados', 'Galletas', 'Chocolates'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdYGN', precio=271.45, categorias=['Caramelos', 'Gomas de mascar', 'Galletas'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdGVH', precio=204.23, categorias=['Mashmelos', 'Gomas de mascar', 'Salados'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdHWK', precio=265.81, categorias=['Gomas de mascar', 'Chocolates'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdDPH', precio=621.85, categorias=['Salados', 'Chocolates', 'Galletas'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdGPG', precio=675.7, categorias=['Chocolates', 'Mashmelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdBOH', precio=986.49, categorias=['Salados', 'Chocolates'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdZBM', precio=733.88, categorias=['Caramelos', 'Galletas'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdOIK', precio=51.78, categorias=['Salados', 'Gomas de mascar', 'Mashmelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdNKV', precio=476.88, categorias=['Salados'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdXWP', precio=950.39, categorias=['Caramelos', 'Gomas de mascar', 'Galletas'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdVRT', precio=668.55, categorias=['Galletas'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdAQI', precio=508.54, categorias=['Mashmelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdVVO', precio=316.09, categorias=['Salados', 'Mashmelos', 'Gomas de mascar'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdYBP', precio=533.43, categorias=['Caramelos', 'Mashmelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdBNL', precio=356.61, categorias=['Salados', 'Chocolates'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdFUU', precio=474.85, categorias=['Mashmelos', 'Galletas'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdKWN', precio=712.52, categorias=['Salados', 'Galletas'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdPRE', precio=193.15, categorias=['Mashmelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdPTY', precio=123.96, categorias=['Salados', 'Chocolates'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdVEM', precio=203.45, categorias=['Salados'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdDLX', precio=215.18, categorias=['Salados'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdVXV', precio=603.99, categorias=['Mashmelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdGDY', precio=246.95, categorias=['Gomas de mascar', 'Chocolates', 'Caramelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdWEY', precio=256.36, categorias=['Galletas', 'Caramelos', 'Chocolates'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdLCV', precio=909.87, categorias=['Gomas de mascar', 'Caramelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdYOQ', precio=418.44, categorias=['Galletas', 'Salados', 'Gomas de mascar'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdNYG', precio=801.76, categorias=['Galletas', 'Gomas de mascar', 'Caramelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdSSV', precio=606.05, categorias=['Gomas de mascar', 'Galletas'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdQJE', precio=410.61, categorias=['Mashmelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdIOV', precio=673.03, categorias=['Caramelos', 'Salados'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdLAP', precio=365.33, categorias=['Chocolates', 'Mashmelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdGET', precio=10.04, categorias=['Gomas de mascar', 'Galletas'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdSHJ', precio=543.65, categorias=['Chocolates'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdBCV', precio=599.77, categorias=['Chocolates', 'Salados'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdUZE', precio=587.79, categorias=['Caramelos', 'Galletas', 'Gomas de mascar'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdOZR', precio=902.73, categorias=['Gomas de mascar', 'Chocolates'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdZNJ', precio=390.05, categorias=['Salados', 'Chocolates'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdISS', precio=950.56, categorias=['Caramelos', 'Chocolates', 'Mashmelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdXVN', precio=2.43, categorias=['Caramelos', 'Chocolates'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdYAA', precio=231.48, categorias=['Gomas de mascar', 'Chocolates', 'Caramelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdOXG', precio=86.27, categorias=['Caramelos', 'Salados'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdBUX', precio=236.32, categorias=['Galletas', 'Chocolates', 'Gomas de mascar'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdPUT', precio=224.95, categorias=['Caramelos', 'Galletas', 'Chocolates'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdFZN', precio=14.72, categorias=['Galletas', 'Gomas de mascar'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdOWX', precio=756.44, categorias=['Chocolates', 'Galletas'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdJVW', precio=317.06, categorias=['Caramelos', 'Gomas de mascar', 'Chocolates'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdBTR', precio=733.22, categorias=['Chocolates', 'Caramelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdALJ', precio=56.8, categorias=['Galletas'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdZQG', precio=325.88, categorias=['Gomas de mascar', 'Galletas'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdFOR', precio=217.94, categorias=['Gomas de mascar'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdLBL', precio=971.43, categorias=['Mashmelos', 'Salados'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdPYH', precio=27.22, categorias=['Caramelos', 'Salados', 'Chocolates'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdMXP', precio=132.24, categorias=['Caramelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdHYV', precio=548.95, categorias=['Mashmelos', 'Chocolates', 'Gomas de mascar'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdYFS', precio=289.62, categorias=['Galletas'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdHWI', precio=47.24, categorias=['Chocolates', 'Mashmelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdXXP', precio=396.76, categorias=['Salados'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdDUK', precio=487.67, categorias=['Galletas', 'Salados', 'Chocolates'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdBFT', precio=933.54, categorias=['Caramelos', 'Gomas de mascar'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdPHT', precio=951.55, categorias=['Chocolates', 'Salados', 'Mashmelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdIIT', precio=969.48, categorias=['Chocolates'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdZSO', precio=129.39, categorias=['Mashmelos', 'Caramelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdFZA', precio=588.97, categorias=['Salados'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdNZM', precio=957.63, categorias=['Caramelos', 'Galletas'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdRHS', precio=955.45, categorias=['Salados'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdUNH', precio=323.25, categorias=['Gomas de mascar'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdIZA', precio=441.87, categorias=['Galletas', 'Gomas de mascar'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdHVN', precio=166.78, categorias=['Caramelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdPUZ', precio=477.01, categorias=['Mashmelos', 'Salados'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdNIS', precio=299.41, categorias=['Galletas'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdXJJ', precio=240.69, categorias=['Caramelos', 'Galletas'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdBTQ', precio=991.39, categorias=['Galletas', 'Chocolates'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdPKU', precio=413.9, categorias=['Salados', 'Gomas de mascar'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdXSN', precio=257.62, categorias=['Salados', 'Chocolates'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdDBJ', precio=460.1, categorias=['Gomas de mascar', 'Galletas', 'Caramelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdRRO', precio=419.43, categorias=['Gomas de mascar', 'Chocolates'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdFSS', precio=581.21, categorias=['Galletas', 'Chocolates'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdGWM', precio=664.08, categorias=['Chocolates', 'Gomas de mascar'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdHRT', precio=871.09, categorias=['Chocolates'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdSBG', precio=242.64, categorias=['Mashmelos', 'Caramelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdEFX', precio=77.17, categorias=['Salados', 'Gomas de mascar', 'Caramelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdDYY', precio=102.51, categorias=['Mashmelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdEIY', precio=372.81, categorias=['Galletas', 'Mashmelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdYDM', precio=436.53, categorias=['Mashmelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdRQD', precio=134.94, categorias=['Mashmelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdFII', precio=169.65, categorias=['Caramelos', 'Galletas', 'Chocolates'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdXWW', precio=263.84, categorias=['Caramelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdYWJ', precio=53.83, categorias=['Galletas', 'Salados', 'Gomas de mascar'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdGNO', precio=15.35, categorias=['Chocolates'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdDFT', precio=821.06, categorias=['Salados', 'Gomas de mascar'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdWOI', precio=268.6, categorias=['Salados', 'Caramelos', 'Mashmelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdDBW', precio=157.5, categorias=['Mashmelos', 'Galletas'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdIJF', precio=749.93, categorias=['Galletas'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdJFM', precio=555.61, categorias=['Caramelos', 'Mashmelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdKRJ', precio=691.82, categorias=['Galletas', 'Mashmelos', 'Salados'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdPWR', precio=827.72, categorias=['Salados', 'Gomas de mascar'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdJUE', precio=419.68, categorias=['Gomas de mascar', 'Chocolates'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdYVA', precio=358.82, categorias=['Mashmelos', 'Chocolates', 'Caramelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdCJJ', precio=499.03, categorias=['Caramelos', 'Mashmelos', 'Gomas de mascar'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdZEF', precio=781.19, categorias=['Salados', 'Gomas de mascar', 'Caramelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdRXJ', precio=939.24, categorias=['Chocolates'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdIKX', precio=896.5, categorias=['Chocolates', 'Mashmelos', 'Salados'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdUAK', precio=145.16, categorias=['Galletas', 'Salados'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdYCE', precio=805.29, categorias=['Salados'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdWEN', precio=567.91, categorias=['Chocolates'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdKGJ', precio=802.47, categorias=['Salados', 'Gomas de mascar', 'Chocolates'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdGXO', precio=416.0, categorias=['Gomas de mascar', 'Galletas', 'Chocolates'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdNUF', precio=284.37, categorias=['Gomas de mascar', 'Caramelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdYXA', precio=489.83, categorias=['Chocolates', 'Gomas de mascar'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdJXY', precio=876.46, categorias=['Caramelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdORP', precio=929.12, categorias=['Galletas', 'Chocolates', 'Salados'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdHSL', precio=882.06, categorias=['Salados', 'Gomas de mascar', 'Galletas'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdWQM', precio=684.98, categorias=['Salados', 'Mashmelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdSMO', precio=30.21, categorias=['Galletas', 'Chocolates'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdEFL', precio=901.95, categorias=['Caramelos', 'Salados', 'Gomas de mascar'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdYOK', precio=836.08, categorias=['Salados', 'Mashmelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdFFP', precio=569.37, categorias=['Mashmelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdJDL', precio=122.24, categorias=['Gomas de mascar', 'Chocolates', 'Galletas'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdCRH', precio=705.27, categorias=['Gomas de mascar', 'Salados', 'Caramelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdRXB', precio=229.76, categorias=['Mashmelos', 'Galletas'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdKVR', precio=29.51, categorias=['Gomas de mascar'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdGHD', precio=255.09, categorias=['Chocolates'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdBYK', precio=293.87, categorias=['Galletas'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdLBX', precio=104.48, categorias=['Chocolates'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdOQB', precio=32.62, categorias=['Salados'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdNLA', precio=160.01, categorias=['Caramelos', 'Mashmelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdMKL', precio=482.82, categorias=['Chocolates', 'Gomas de mascar', 'Mashmelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdKZZ', precio=965.82, categorias=['Salados', 'Caramelos', 'Galletas'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdOCU', precio=288.8, categorias=['Salados', 'Gomas de mascar', 'Chocolates'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdSKJ', precio=808.38, categorias=['Gomas de mascar', 'Mashmelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdFPI', precio=989.08, categorias=['Galletas', 'Caramelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdSYI', precio=614.5, categorias=['Galletas'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdWCU', precio=724.1, categorias=['Caramelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdMBO', precio=730.88, categorias=['Caramelos', 'Salados', 'Gomas de mascar'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdLHH', precio=743.98, categorias=['Galletas', 'Chocolates'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdBBN', precio=57.3, categorias=['Salados', 'Galletas'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdFYV', precio=177.6, categorias=['Caramelos', 'Salados'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdFKO', precio=289.64, categorias=['Mashmelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdVUD', precio=852.43, categorias=['Galletas', 'Gomas de mascar'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdXPW', precio=297.85, categorias=['Chocolates', 'Galletas'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdWQZ', precio=89.95, categorias=['Gomas de mascar', 'Caramelos', 'Galletas'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdTBV', precio=779.37, categorias=['Chocolates'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdBYP', precio=790.77, categorias=['Gomas de mascar'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdONW', precio=798.44, categorias=['Mashmelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdLUP', precio=519.44, categorias=['Salados', 'Gomas de mascar', 'Caramelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdPAA', precio=917.29, categorias=['Chocolates'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdUSE', precio=249.32, categorias=['Mashmelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdBIW', precio=126.45, categorias=['Chocolates', 'Gomas de mascar'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdNSK', precio=609.2, categorias=['Gomas de mascar', 'Galletas'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdMEO', precio=464.02, categorias=['Galletas', 'Mashmelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdXCZ', precio=439.43, categorias=['Caramelos', 'Chocolates'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdFJV', precio=484.55, categorias=['Chocolates'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdQUY', precio=907.32, categorias=['Caramelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdBKC', precio=187.32, categorias=['Mashmelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdLZN', precio=889.63, categorias=['Mashmelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdVPT', precio=126.7, categorias=['Chocolates'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdTAY', precio=581.55, categorias=['Galletas'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdPQQ', precio=335.44, categorias=['Chocolates', 'Caramelos', 'Mashmelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdXGK', precio=18.22, categorias=['Mashmelos', 'Gomas de mascar'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdSKL', precio=619.4, categorias=['Galletas', 'Salados'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdNGE', precio=822.08, categorias=['Mashmelos', 'Caramelos', 'Chocolates'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdJCQ', precio=811.58, categorias=['Salados', 'Gomas de mascar', 'Chocolates'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdACS', precio=547.4, categorias=['Chocolates'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdLZD', precio=432.83, categorias=['Caramelos', 'Gomas de mascar'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdOPY', precio=969.84, categorias=['Mashmelos', 'Caramelos', 'Salados'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdCMP', precio=178.67, categorias=['Caramelos', 'Gomas de mascar', 'Galletas'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdBPO', precio=39.51, categorias=['Chocolates'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdSLL', precio=409.7, categorias=['Caramelos', 'Gomas de mascar', 'Salados'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdOBE', precio=634.49, categorias=['Galletas', 'Salados'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdZMV', precio=338.41, categorias=['Gomas de mascar', 'Chocolates', 'Galletas'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdOND', precio=957.89, categorias=['Salados'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdCJI', precio=758.42, categorias=['Salados', 'Chocolates', 'Galletas'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdGVG', precio=223.4, categorias=['Galletas'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdIAW', precio=211.16, categorias=['Chocolates'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdCGV', precio=277.91, categorias=['Chocolates', 'Gomas de mascar'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdNQH', precio=926.12, categorias=['Galletas', 'Salados', 'Gomas de mascar'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdCFI', precio=986.74, categorias=['Chocolates'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdOMP', precio=49.35, categorias=['Galletas'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdDAZ', precio=465.65, categorias=['Gomas de mascar'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdKDF', precio=689.03, categorias=['Mashmelos', 'Chocolates'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdUDA', precio=656.61, categorias=['Mashmelos', 'Salados', 'Caramelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdKBA', precio=230.81, categorias=['Chocolates', 'Caramelos', 'Gomas de mascar'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdEFK', precio=619.88, categorias=['Galletas', 'Gomas de mascar', 'Mashmelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdRWW', precio=256.09, categorias=['Salados', 'Galletas'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdWZJ', precio=239.84, categorias=['Gomas de mascar'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdIOY', precio=364.26, categorias=['Salados', 'Galletas'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdGQP', precio=132.63, categorias=['Salados', 'Mashmelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdGFR', precio=890.53, categorias=['Gomas de mascar', 'Salados'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdVVS', precio=210.69, categorias=['Galletas', 'Mashmelos', 'Caramelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdFEQ', precio=940.0, categorias=['Chocolates', 'Gomas de mascar', 'Galletas'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdRSA', precio=355.37, categorias=['Mashmelos', 'Chocolates', 'Salados'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdYXC', precio=326.32, categorias=['Galletas', 'Mashmelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdRMB', precio=682.16, categorias=['Caramelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdSKU', precio=722.78, categorias=['Mashmelos', 'Caramelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdMSU', precio=284.18, categorias=['Mashmelos', 'Salados'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdOSS', precio=93.31, categorias=['Caramelos', 'Mashmelos', 'Chocolates'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdGLY', precio=73.95, categorias=['Gomas de mascar', 'Salados', 'Caramelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdWJU', precio=69.2, categorias=['Chocolates', 'Mashmelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdOOH', precio=915.56, categorias=['Salados'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdMRS', precio=562.41, categorias=['Caramelos', 'Galletas'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdNSX', precio=608.11, categorias=['Chocolates', 'Mashmelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdOCC', precio=659.79, categorias=['Salados'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdIGB', precio=802.16, categorias=['Galletas'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdRKR', precio=295.91, categorias=['Galletas', 'Chocolates', 'Mashmelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdHHD', precio=2.3, categorias=['Chocolates', 'Mashmelos', 'Caramelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdTTL', precio=99.91, categorias=['Mashmelos', 'Galletas'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdQYL', precio=789.97, categorias=['Caramelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdVAJ', precio=361.31, categorias=['Salados'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdLMW', precio=200.42, categorias=['Gomas de mascar', 'Chocolates'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdEND', precio=80.7, categorias=['Salados', 'Mashmelos', 'Gomas de mascar'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdCLJ', precio=423.36, categorias=['Mashmelos', 'Chocolates'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdUET', precio=91.83, categorias=['Chocolates'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdOJW', precio=503.83, categorias=['Galletas', 'Salados'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdFBF', precio=448.51, categorias=['Salados'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdXBG', precio=247.72, categorias=['Caramelos', 'Gomas de mascar', 'Mashmelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdLGO', precio=169.01, categorias=['Salados', 'Caramelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdZBD', precio=938.3, categorias=['Galletas'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdNJY', precio=348.22, categorias=['Salados', 'Chocolates', 'Mashmelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdKVJ', precio=414.53, categorias=['Galletas', 'Caramelos', 'Gomas de mascar'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdKZU', precio=8.78, categorias=['Caramelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdHHR', precio=476.76, categorias=['Gomas de mascar'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdLMG', precio=208.93, categorias=['Gomas de mascar', 'Mashmelos', 'Galletas'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdDAY', precio=202.68, categorias=['Chocolates', 'Salados', 'Caramelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdOSU', precio=961.71, categorias=['Salados', 'Gomas de mascar'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdPWC', precio=22.66, categorias=['Chocolates'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdXCJ', precio=355.96, categorias=['Galletas', 'Salados', 'Caramelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdAYR', precio=244.3, categorias=['Salados', 'Gomas de mascar', 'Mashmelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdKMD', precio=205.46, categorias=['Chocolates', 'Galletas'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdXNL', precio=56.24, categorias=['Galletas', 'Chocolates', 'Caramelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdGQL', precio=298.35, categorias=['Caramelos', 'Mashmelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdJFY', precio=745.3, categorias=['Gomas de mascar', 'Caramelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdNJU', precio=893.86, categorias=['Caramelos', 'Galletas'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdRVC', precio=938.5, categorias=['Salados', 'Gomas de mascar'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdIGH', precio=104.69, categorias=['Gomas de mascar', 'Salados', 'Galletas'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdSSJ', precio=633.38, categorias=['Caramelos', 'Gomas de mascar', 'Galletas'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdCYL', precio=24.81, categorias=['Caramelos', 'Mashmelos', 'Gomas de mascar'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdHJC', precio=593.65, categorias=['Gomas de mascar', 'Mashmelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdXVS', precio=954.57, categorias=['Salados'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdNQU', precio=857.02, categorias=['Mashmelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdJOO', precio=795.33, categorias=['Chocolates', 'Galletas', 'Salados'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdJBU', precio=792.71, categorias=['Mashmelos', 'Chocolates', 'Gomas de mascar'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdNPR', precio=727.99, categorias=['Mashmelos', 'Chocolates'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdOGB', precio=356.83, categorias=['Caramelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdDYM', precio=910.35, categorias=['Gomas de mascar'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdNJD', precio=28.25, categorias=['Galletas', 'Mashmelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdGAA', precio=695.29, categorias=['Mashmelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdCHB', precio=17.21, categorias=['Galletas'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdFQB', precio=591.9, categorias=['Mashmelos', 'Salados'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdAMR', precio=65.69, categorias=['Salados', 'Chocolates'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdQJS', precio=645.83, categorias=['Salados', 'Caramelos', 'Galletas'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdKGG', precio=728.82, categorias=['Salados', 'Chocolates'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdJXM', precio=127.75, categorias=['Mashmelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdCJQ', precio=150.66, categorias=['Salados', 'Galletas', 'Gomas de mascar'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdCCU', precio=162.9, categorias=['Galletas'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdEFQ', precio=901.53, categorias=['Mashmelos', 'Chocolates'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdCSS', precio=784.12, categorias=['Chocolates'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdJRM', precio=748.24, categorias=['Gomas de mascar', 'Salados', 'Caramelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdMBP', precio=760.07, categorias=['Gomas de mascar', 'Galletas'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdOVU', precio=982.8, categorias=['Galletas', 'Chocolates', 'Caramelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdBEP', precio=988.55, categorias=['Chocolates', 'Mashmelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdWIK', precio=273.28, categorias=['Mashmelos', 'Galletas', 'Salados'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdRIR', precio=473.29, categorias=['Galletas', 'Mashmelos', 'Chocolates'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdWTT', precio=318.24, categorias=['Gomas de mascar', 'Chocolates', 'Salados'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdRBE', precio=520.07, categorias=['Mashmelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdDTG', precio=763.44, categorias=['Mashmelos', 'Gomas de mascar'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdDXS', precio=334.84, categorias=['Salados'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdZVE', precio=521.51, categorias=['Gomas de mascar'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdGUK', precio=757.42, categorias=['Salados', 'Chocolates'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdGZR', precio=939.28, categorias=['Galletas', 'Gomas de mascar'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdAKT', precio=342.37, categorias=['Salados'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdCTS', precio=295.06, categorias=['Caramelos', 'Salados'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdVDU', precio=534.29, categorias=['Galletas', 'Salados', 'Caramelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdTSW', precio=894.25, categorias=['Caramelos', 'Gomas de mascar'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdYVB', precio=118.07, categorias=['Galletas', 'Chocolates'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdHPK', precio=463.84, categorias=['Gomas de mascar', 'Chocolates'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdXUI', precio=578.61, categorias=['Chocolates'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdMBN', precio=283.24, categorias=['Mashmelos', 'Gomas de mascar', 'Salados'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdDOP', precio=975.27, categorias=['Mashmelos', 'Chocolates', 'Salados'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdBGY', precio=439.7, categorias=['Mashmelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdCRZ', precio=170.0, categorias=['Galletas', 'Caramelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdJRU', precio=402.24, categorias=['Galletas', 'Gomas de mascar', 'Chocolates'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdBKU', precio=345.39, categorias=['Caramelos', 'Salados'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdRNR', precio=666.25, categorias=['Gomas de mascar'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdDJN', precio=935.44, categorias=['Galletas', 'Gomas de mascar'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdHXT', precio=519.75, categorias=['Gomas de mascar', 'Salados', 'Galletas'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdNRW', precio=536.05, categorias=['Mashmelos', 'Salados', 'Gomas de mascar'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdEXP', precio=55.85, categorias=['Galletas', 'Caramelos', 'Salados'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdIVE', precio=897.99, categorias=['Galletas'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdBNT', precio=375.57, categorias=['Gomas de mascar', 'Chocolates'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdTWE', precio=687.76, categorias=['Galletas', 'Chocolates', 'Mashmelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdZYW', precio=672.96, categorias=['Mashmelos', 'Gomas de mascar', 'Salados'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdIPO', precio=246.01, categorias=['Gomas de mascar', 'Salados', 'Galletas'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdLAC', precio=499.48, categorias=['Gomas de mascar', 'Salados'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdSEA', precio=285.12, categorias=['Caramelos', 'Gomas de mascar'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdVXP', precio=550.87, categorias=['Caramelos', 'Galletas'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdAFS', precio=790.99, categorias=['Chocolates', 'Salados', 'Gomas de mascar'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdSQT', precio=545.71, categorias=['Mashmelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdGSN', precio=702.43, categorias=['Caramelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdOIM', precio=883.07, categorias=['Gomas de mascar', 'Salados', 'Mashmelos'], en_venta=True)
#
# Ahora puede registrar manualmente:
