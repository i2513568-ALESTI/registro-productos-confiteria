# %%
# -*- coding: utf-8 -*-
"""
Genera data sintética de productos para la confitería Dulcino.
- Aplica TODAS las validaciones de la historia de usuario.
- Guarda en datos_sinteticos/products.csv (append seguro).
- Puede generar en batch (sintético) y también aceptar un registro manual (modo demo).
"""

from __future__ import annotations
import os, csv, random, string
from dataclasses import dataclass, asdict
from datetime import datetime
from typing import List

# -------------------------------
# Configuración / constantes
# -------------------------------
DATA_DIR = os.path.join("datos_sinteticos")
CSV_PATH = os.path.join(DATA_DIR, "products.csv")

CATEGORIAS_VALIDAS = ["Chocolates", "Caramelos", "Mashmelos", 
                      "Galletas", "Salados", "Gomas de mascar"]

os.makedirs(DATA_DIR, exist_ok=True)
if not os.path.exists(CSV_PATH):
    with open(CSV_PATH, "w", newline="", encoding="utf-8") as f:
        writer = csv.writer(f)
        writer.writerow(["Nombre", "Precio", "Categorías", "En venta", "FechaRegistro"])

# -------------------------------
# Modelo de datos
# -------------------------------
@dataclass
class Producto:
    nombre: str
    precio: float
    categorias: List[str]
    en_venta: bool
    
    def validar(self) -> List[str]:
        errores = []
        # Nombre
        if len(self.nombre.strip()) == 0 or len(self.nombre) > 20:
            errores.append("El nombre debe tener máximo 20 caracteres y no estar vacío.")
        # Precio
        if not (0 < self.precio < 999):
            errores.append("El precio debe ser mayor a 0 y menor a 999.")
        # Categorías
        if len(self.categorias) == 0:
            errores.append("Debe seleccionar al menos una categoría.")
        for c in self.categorias:
            if c not in CATEGORIAS_VALIDAS:
                errores.append(f"Categoría no válida: {c}")
        return errores

    def guardar(self):
        errores = self.validar()
        if errores:
            raise ValueError("Errores de validación: " + "; ".join(errores))
        with open(CSV_PATH, "a", newline="", encoding="utf-8") as f:
            writer = csv.writer(f)
            writer.writerow([
                self.nombre, 
                self.precio, 
                ";".join(self.categorias), 
                "Sí" if self.en_venta else "No", 
                datetime.now().isoformat()
            ])

# -------------------------------
# Funciones auxiliares
# -------------------------------
def generar_nombre_aleatorio():
    return "Prod" + ''.join(random.choices(string.ascii_uppercase, k=3))

def generar_producto_aleatorio() -> Producto:
    nombre = generar_nombre_aleatorio()
    precio = round(random.uniform(1, 998), 2)
    categorias = random.sample(CATEGORIAS_VALIDAS, random.randint(1, 3))
    en_venta = random.choice([True, False])
    return Producto(nombre, precio, categorias, en_venta)

def generar_batch(n: int = 10):
    for _ in range(n):
        p = generar_producto_aleatorio()
        try:
            p.guardar()
            print(f"✅ Producto agregado: {p}")
        except Exception as e:
            print(f"❌ Error: {e}")

# -------------------------------
# Modo demo (manual)
# -------------------------------
def registrar_manual():
    nombre = input("Ingrese nombre del producto: ")
    try:
        precio = float(input("Ingrese precio del producto (S/.): "))
    except:
        print("⚠️ Por favor verifique el campo del precio.")
        return
    categorias = input("Ingrese categorías separadas por coma: ").split(",")
    categorias = [c.strip() for c in categorias]
    en_venta = input("¿Está en venta? (s/n): ").lower() == "s"
    producto = Producto(nombre, precio, categorias, en_venta)
    try:
        producto.guardar()
        print("✅ Felicidades su producto se agregó.")
    except Exception as e:
        print("❌ Lo sentimos no pudo crear este producto.")
        print(e)

# -------------------------------
# Ejecución de ejemplo
# -------------------------------
if __name__ == "__main__":
    print("Generando lote de prueba (5 productos)...")
    generar_batch(300)
    print("\nAhora puede registrar manualmente:")
    # registrar_manual()
# Out:
# Generando lote de prueba (5 productos)...
# ✅ Producto agregado: Producto(nombre='ProdLIS', precio=989.89, categorias=['Chocolates', 'Caramelos', 'Salados'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdOMU', precio=634.43, categorias=['Mashmelos', 'Salados', 'Chocolates'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdHEX', precio=613.22, categorias=['Chocolates', 'Gomas de mascar', 'Mashmelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdTYE', precio=705.5, categorias=['Mashmelos', 'Caramelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdRAC', precio=106.33, categorias=['Salados', 'Mashmelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdTAN', precio=829.16, categorias=['Caramelos', 'Chocolates', 'Salados'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdNSW', precio=405.69, categorias=['Galletas', 'Gomas de mascar', 'Mashmelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdRQL', precio=825.6, categorias=['Mashmelos', 'Galletas', 'Chocolates'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdOSO', precio=409.17, categorias=['Chocolates', 'Salados'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdUYG', precio=713.27, categorias=['Caramelos', 'Salados', 'Mashmelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdFLC', precio=90.67, categorias=['Galletas'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdXOA', precio=942.86, categorias=['Chocolates', 'Caramelos', 'Mashmelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdGUV', precio=819.54, categorias=['Salados', 'Galletas', 'Gomas de mascar'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdKZF', precio=917.02, categorias=['Caramelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdLMA', precio=636.08, categorias=['Gomas de mascar', 'Galletas'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdXMV', precio=331.42, categorias=['Gomas de mascar'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdXNX', precio=340.93, categorias=['Mashmelos', 'Chocolates'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdMIU', precio=213.94, categorias=['Chocolates'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdBXS', precio=437.06, categorias=['Caramelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdVXX', precio=167.52, categorias=['Galletas'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdQDP', precio=415.35, categorias=['Salados'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdJNR', precio=307.68, categorias=['Galletas'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdLJA', precio=392.87, categorias=['Gomas de mascar', 'Salados'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdFLR', precio=85.35, categorias=['Gomas de mascar', 'Caramelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdDWO', precio=308.82, categorias=['Caramelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdGZG', precio=651.98, categorias=['Mashmelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdTAY', precio=933.18, categorias=['Salados', 'Galletas', 'Chocolates'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdJBH', precio=115.96, categorias=['Mashmelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdBPW', precio=864.29, categorias=['Chocolates', 'Salados'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdOXK', precio=448.96, categorias=['Gomas de mascar', 'Mashmelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdESO', precio=584.01, categorias=['Galletas', 'Chocolates', 'Salados'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdEWZ', precio=464.08, categorias=['Gomas de mascar', 'Salados', 'Mashmelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdPGP', precio=539.34, categorias=['Mashmelos', 'Galletas'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdLZD', precio=377.47, categorias=['Caramelos', 'Salados', 'Gomas de mascar'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdNDY', precio=142.58, categorias=['Salados', 'Gomas de mascar'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdBDP', precio=349.51, categorias=['Caramelos', 'Galletas'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdLQY', precio=501.63, categorias=['Salados', 'Chocolates'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdYCZ', precio=671.99, categorias=['Caramelos', 'Galletas', 'Salados'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdQAU', precio=25.59, categorias=['Mashmelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdQAS', precio=971.68, categorias=['Caramelos', 'Gomas de mascar'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdLIK', precio=838.76, categorias=['Mashmelos', 'Chocolates'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdURO', precio=168.98, categorias=['Mashmelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdJFJ', precio=737.8, categorias=['Chocolates'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdBES', precio=385.94, categorias=['Chocolates', 'Mashmelos', 'Galletas'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdGET', precio=600.16, categorias=['Gomas de mascar'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdLQH', precio=892.63, categorias=['Mashmelos', 'Chocolates'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdIDX', precio=677.79, categorias=['Chocolates'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdBJQ', precio=569.46, categorias=['Caramelos', 'Mashmelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdRKY', precio=548.81, categorias=['Caramelos', 'Gomas de mascar', 'Salados'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdFWS', precio=932.2, categorias=['Salados', 'Galletas'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdMZU', precio=675.49, categorias=['Chocolates', 'Salados', 'Gomas de mascar'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdZIO', precio=246.24, categorias=['Chocolates'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdXQA', precio=751.88, categorias=['Salados'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdZCC', precio=221.92, categorias=['Chocolates', 'Galletas', 'Gomas de mascar'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdLRN', precio=392.64, categorias=['Galletas'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdANI', precio=951.15, categorias=['Mashmelos', 'Gomas de mascar', 'Salados'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdIHT', precio=216.56, categorias=['Mashmelos', 'Caramelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdYIW', precio=314.68, categorias=['Salados', 'Caramelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdCEH', precio=952.94, categorias=['Caramelos', 'Mashmelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdEWW', precio=884.44, categorias=['Gomas de mascar', 'Mashmelos', 'Galletas'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdZCR', precio=221.09, categorias=['Mashmelos', 'Galletas'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdZCY', precio=275.58, categorias=['Gomas de mascar', 'Caramelos', 'Galletas'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdZRO', precio=507.94, categorias=['Salados', 'Mashmelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdLIE', precio=228.06, categorias=['Mashmelos', 'Salados'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdTJF', precio=548.51, categorias=['Galletas', 'Chocolates'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdHTU', precio=265.89, categorias=['Mashmelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdYVS', precio=816.85, categorias=['Salados'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdWOR', precio=304.91, categorias=['Chocolates', 'Mashmelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdJDT', precio=389.64, categorias=['Chocolates', 'Galletas'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdNFM', precio=322.21, categorias=['Mashmelos', 'Salados', 'Chocolates'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdYLK', precio=560.31, categorias=['Mashmelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdBQV', precio=456.26, categorias=['Salados'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdATW', precio=736.49, categorias=['Mashmelos', 'Gomas de mascar'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdYSW', precio=17.6, categorias=['Gomas de mascar', 'Mashmelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdOYY', precio=94.24, categorias=['Salados', 'Gomas de mascar', 'Galletas'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdZCF', precio=544.29, categorias=['Salados', 'Caramelos', 'Mashmelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdDWO', precio=705.91, categorias=['Caramelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdCVV', precio=244.06, categorias=['Gomas de mascar'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdGGL', precio=941.37, categorias=['Galletas', 'Gomas de mascar'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdHIU', precio=774.91, categorias=['Mashmelos', 'Gomas de mascar'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdUHE', precio=681.03, categorias=['Caramelos', 'Salados'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdXRT', precio=480.79, categorias=['Galletas', 'Caramelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdDVW', precio=179.14, categorias=['Salados', 'Galletas', 'Chocolates'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdKMV', precio=722.0, categorias=['Caramelos', 'Galletas', 'Salados'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdZPD', precio=516.56, categorias=['Mashmelos', 'Chocolates'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdBUN', precio=504.43, categorias=['Gomas de mascar', 'Galletas'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdTWN', precio=793.92, categorias=['Gomas de mascar', 'Caramelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdUDS', precio=863.9, categorias=['Galletas', 'Salados'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdUBR', precio=296.85, categorias=['Mashmelos', 'Salados'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdZAO', precio=62.09, categorias=['Gomas de mascar', 'Caramelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdJCS', precio=517.71, categorias=['Salados', 'Caramelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdCOT', precio=510.78, categorias=['Mashmelos', 'Galletas'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdNCA', precio=363.28, categorias=['Galletas', 'Mashmelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdCDV', precio=574.88, categorias=['Caramelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdKGP', precio=89.76, categorias=['Galletas', 'Caramelos', 'Mashmelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdNZA', precio=559.73, categorias=['Caramelos', 'Mashmelos', 'Gomas de mascar'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdFWX', precio=392.03, categorias=['Galletas'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdZFX', precio=642.04, categorias=['Gomas de mascar'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdJGE', precio=803.06, categorias=['Salados'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdBZK', precio=761.75, categorias=['Chocolates'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdCNZ', precio=793.74, categorias=['Chocolates', 'Gomas de mascar'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdZGW', precio=760.24, categorias=['Mashmelos', 'Chocolates', 'Salados'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdMQB', precio=654.26, categorias=['Galletas'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdGDL', precio=198.36, categorias=['Salados', 'Gomas de mascar', 'Caramelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdONU', precio=76.46, categorias=['Gomas de mascar'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdRZZ', precio=289.67, categorias=['Caramelos', 'Chocolates'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdGTX', precio=65.24, categorias=['Caramelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdUTZ', precio=94.14, categorias=['Gomas de mascar', 'Salados'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdJJV', precio=534.97, categorias=['Gomas de mascar', 'Salados', 'Galletas'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdCQB', precio=439.83, categorias=['Galletas'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdYEX', precio=768.99, categorias=['Gomas de mascar', 'Mashmelos', 'Chocolates'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdJWU', precio=283.36, categorias=['Mashmelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdCTI', precio=758.81, categorias=['Mashmelos', 'Salados', 'Gomas de mascar'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdSOQ', precio=697.79, categorias=['Gomas de mascar', 'Chocolates', 'Galletas'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdKAD', precio=336.56, categorias=['Salados'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdGOO', precio=73.17, categorias=['Mashmelos', 'Caramelos', 'Chocolates'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdOIX', precio=471.7, categorias=['Salados'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdKHR', precio=55.86, categorias=['Galletas', 'Caramelos', 'Salados'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdKXN', precio=341.78, categorias=['Salados', 'Mashmelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdOGJ', precio=630.29, categorias=['Caramelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdTPQ', precio=843.51, categorias=['Salados', 'Galletas', 'Gomas de mascar'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdYRT', precio=189.71, categorias=['Galletas'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdBJS', precio=194.83, categorias=['Mashmelos', 'Salados'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdKLM', precio=217.83, categorias=['Caramelos', 'Salados'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdNFB', precio=463.55, categorias=['Galletas'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdJTF', precio=941.02, categorias=['Caramelos', 'Galletas'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdPVW', precio=975.14, categorias=['Mashmelos', 'Salados'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdMXK', precio=729.09, categorias=['Galletas'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdHTP', precio=983.37, categorias=['Galletas', 'Chocolates'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdACJ', precio=950.35, categorias=['Gomas de mascar'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdYOP', precio=549.79, categorias=['Chocolates', 'Gomas de mascar'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdDVU', precio=614.43, categorias=['Gomas de mascar', 'Chocolates'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdJNA', precio=166.24, categorias=['Caramelos', 'Salados', 'Galletas'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdNNA', precio=306.76, categorias=['Galletas'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdKII', precio=971.1, categorias=['Salados', 'Mashmelos', 'Gomas de mascar'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdCQB', precio=383.64, categorias=['Salados', 'Galletas'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdIWD', precio=127.09, categorias=['Salados', 'Mashmelos', 'Caramelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdIRL', precio=452.45, categorias=['Caramelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdVRI', precio=797.6, categorias=['Chocolates'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdTES', precio=30.95, categorias=['Mashmelos', 'Caramelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdEZC', precio=591.42, categorias=['Salados', 'Gomas de mascar'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdDEE', precio=343.23, categorias=['Mashmelos', 'Salados', 'Caramelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdOCF', precio=664.56, categorias=['Chocolates', 'Salados'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdOQP', precio=398.99, categorias=['Chocolates'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdTDU', precio=599.23, categorias=['Gomas de mascar', 'Chocolates', 'Salados'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdQII', precio=946.59, categorias=['Gomas de mascar', 'Mashmelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdPBU', precio=229.89, categorias=['Gomas de mascar', 'Salados', 'Caramelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdNYD', precio=765.45, categorias=['Gomas de mascar', 'Galletas'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdYOR', precio=8.83, categorias=['Gomas de mascar', 'Mashmelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdHPK', precio=948.01, categorias=['Chocolates'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdOFD', precio=326.09, categorias=['Chocolates', 'Caramelos', 'Mashmelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdLTF', precio=897.81, categorias=['Mashmelos', 'Caramelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdEDG', precio=88.16, categorias=['Chocolates'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdXHG', precio=155.16, categorias=['Caramelos', 'Gomas de mascar'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdGUY', precio=767.03, categorias=['Galletas'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdABZ', precio=584.23, categorias=['Caramelos', 'Galletas', 'Gomas de mascar'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdXPD', precio=758.41, categorias=['Mashmelos', 'Caramelos', 'Salados'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdRMQ', precio=915.53, categorias=['Mashmelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdXKB', precio=398.76, categorias=['Gomas de mascar'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdHFI', precio=318.09, categorias=['Galletas', 'Gomas de mascar', 'Salados'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdWQE', precio=485.76, categorias=['Gomas de mascar'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdCGR', precio=958.45, categorias=['Caramelos', 'Mashmelos', 'Chocolates'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdNGT', precio=940.49, categorias=['Salados', 'Chocolates', 'Gomas de mascar'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdVEQ', precio=713.92, categorias=['Salados', 'Chocolates'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdBVH', precio=200.87, categorias=['Galletas'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdIDJ', precio=803.27, categorias=['Mashmelos', 'Gomas de mascar'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdOUS', precio=494.49, categorias=['Galletas', 'Gomas de mascar'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdVBX', precio=467.04, categorias=['Chocolates', 'Mashmelos', 'Salados'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdPMV', precio=342.15, categorias=['Chocolates'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdDHQ', precio=213.78, categorias=['Galletas'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdARR', precio=81.87, categorias=['Mashmelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdURY', precio=207.31, categorias=['Galletas', 'Gomas de mascar'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdPGP', precio=900.91, categorias=['Salados', 'Chocolates', 'Galletas'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdZHW', precio=891.39, categorias=['Gomas de mascar', 'Galletas', 'Caramelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdIEW', precio=377.91, categorias=['Chocolates', 'Mashmelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdRLE', precio=865.12, categorias=['Mashmelos', 'Gomas de mascar'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdWXK', precio=581.85, categorias=['Gomas de mascar'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdXUB', precio=986.56, categorias=['Galletas'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdZTA', precio=236.53, categorias=['Mashmelos', 'Gomas de mascar', 'Chocolates'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdNZR', precio=62.36, categorias=['Chocolates'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdSQQ', precio=477.39, categorias=['Salados', 'Gomas de mascar'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdPFW', precio=337.21, categorias=['Chocolates', 'Mashmelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdCFM', precio=970.52, categorias=['Caramelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdYOX', precio=420.69, categorias=['Galletas'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdYFJ', precio=712.31, categorias=['Gomas de mascar', 'Chocolates'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdRYK', precio=601.14, categorias=['Gomas de mascar'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdUMS', precio=750.59, categorias=['Mashmelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdAFA', precio=405.52, categorias=['Chocolates', 'Galletas'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdKDL', precio=289.15, categorias=['Salados', 'Gomas de mascar', 'Chocolates'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdKUY', precio=772.52, categorias=['Salados', 'Galletas'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdXJQ', precio=689.77, categorias=['Caramelos', 'Chocolates'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdZOI', precio=105.02, categorias=['Salados', 'Chocolates', 'Galletas'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdFLK', precio=336.14, categorias=['Galletas'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdJTJ', precio=611.01, categorias=['Salados'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdQCS', precio=913.13, categorias=['Salados', 'Chocolates', 'Gomas de mascar'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdXCI', precio=550.32, categorias=['Caramelos', 'Galletas', 'Gomas de mascar'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdMSL', precio=589.82, categorias=['Chocolates', 'Salados', 'Caramelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdBKY', precio=592.91, categorias=['Gomas de mascar', 'Mashmelos', 'Galletas'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdFCA', precio=857.52, categorias=['Caramelos', 'Chocolates'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdRDT', precio=662.49, categorias=['Galletas'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdCUO', precio=9.11, categorias=['Mashmelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdZGI', precio=355.28, categorias=['Mashmelos', 'Caramelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdDOW', precio=517.73, categorias=['Salados', 'Mashmelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdCZD', precio=768.77, categorias=['Caramelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdHDE', precio=55.18, categorias=['Mashmelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdVNA', precio=559.63, categorias=['Chocolates', 'Mashmelos', 'Caramelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdDGZ', precio=614.45, categorias=['Gomas de mascar'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdUQQ', precio=325.21, categorias=['Gomas de mascar'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdCLH', precio=752.21, categorias=['Galletas', 'Mashmelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdJWP', precio=672.83, categorias=['Galletas'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdHGI', precio=993.42, categorias=['Caramelos', 'Mashmelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdSYL', precio=949.37, categorias=['Gomas de mascar', 'Chocolates'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdBVQ', precio=602.25, categorias=['Gomas de mascar', 'Chocolates'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdAMV', precio=375.95, categorias=['Salados', 'Mashmelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdSTX', precio=329.61, categorias=['Mashmelos', 'Caramelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdCMV', precio=658.48, categorias=['Chocolates', 'Galletas', 'Caramelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdAGQ', precio=981.54, categorias=['Chocolates'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdLUO', precio=330.68, categorias=['Galletas', 'Mashmelos', 'Gomas de mascar'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdUBD', precio=677.94, categorias=['Salados', 'Gomas de mascar', 'Galletas'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdDRJ', precio=249.97, categorias=['Gomas de mascar', 'Chocolates'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdHBF', precio=11.21, categorias=['Salados'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdXLD', precio=895.31, categorias=['Chocolates'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdAPK', precio=763.63, categorias=['Gomas de mascar'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdKMV', precio=439.95, categorias=['Mashmelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdQOV', precio=212.45, categorias=['Galletas', 'Gomas de mascar'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdPMM', precio=598.97, categorias=['Chocolates'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdICC', precio=109.78, categorias=['Salados'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdVDU', precio=919.68, categorias=['Mashmelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdXOK', precio=703.27, categorias=['Caramelos', 'Gomas de mascar', 'Galletas'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdTOA', precio=643.08, categorias=['Caramelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdVJS', precio=234.36, categorias=['Mashmelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdCTM', precio=177.64, categorias=['Chocolates', 'Caramelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdOBG', precio=745.05, categorias=['Galletas', 'Caramelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdBRP', precio=649.95, categorias=['Chocolates', 'Mashmelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdKQH', precio=647.01, categorias=['Galletas', 'Chocolates', 'Caramelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdYNH', precio=949.88, categorias=['Chocolates', 'Mashmelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdUMI', precio=231.52, categorias=['Salados', 'Chocolates'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdJEE', precio=767.82, categorias=['Mashmelos', 'Gomas de mascar', 'Galletas'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdQAK', precio=56.68, categorias=['Galletas', 'Gomas de mascar', 'Mashmelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdALH', precio=40.61, categorias=['Gomas de mascar'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdIWV', precio=457.68, categorias=['Mashmelos', 'Caramelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdNZH', precio=837.49, categorias=['Galletas', 'Gomas de mascar', 'Caramelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdAZE', precio=837.59, categorias=['Mashmelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdOLR', precio=184.32, categorias=['Chocolates', 'Caramelos', 'Gomas de mascar'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdSTQ', precio=295.2, categorias=['Mashmelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdQWN', precio=20.57, categorias=['Chocolates'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdDMD', precio=96.67, categorias=['Salados'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdDDA', precio=378.66, categorias=['Salados', 'Gomas de mascar', 'Caramelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdKTV', precio=639.45, categorias=['Salados', 'Galletas'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdTDW', precio=279.37, categorias=['Caramelos', 'Chocolates'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdMBC', precio=594.05, categorias=['Caramelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdODT', precio=828.82, categorias=['Galletas', 'Salados'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdIPN', precio=449.35, categorias=['Gomas de mascar', 'Caramelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdVUO', precio=410.11, categorias=['Chocolates'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdENQ', precio=881.35, categorias=['Gomas de mascar'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdVGM', precio=906.43, categorias=['Chocolates', 'Galletas', 'Mashmelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdGJE', precio=891.1, categorias=['Mashmelos', 'Galletas'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdEXB', precio=189.99, categorias=['Mashmelos', 'Salados', 'Gomas de mascar'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdVKM', precio=759.39, categorias=['Gomas de mascar', 'Chocolates', 'Galletas'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdKGI', precio=637.97, categorias=['Caramelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdTCA', precio=708.51, categorias=['Galletas', 'Gomas de mascar'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdFNS', precio=862.76, categorias=['Chocolates', 'Mashmelos', 'Salados'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdWJG', precio=173.37, categorias=['Salados'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdRPN', precio=271.72, categorias=['Salados', 'Chocolates', 'Mashmelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdBXS', precio=399.92, categorias=['Caramelos', 'Galletas'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdFLG', precio=517.52, categorias=['Chocolates'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdUCH', precio=970.14, categorias=['Caramelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdQTV', precio=417.44, categorias=['Mashmelos', 'Galletas'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdORU', precio=846.78, categorias=['Mashmelos', 'Gomas de mascar', 'Galletas'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdCSH', precio=97.32, categorias=['Gomas de mascar', 'Chocolates', 'Galletas'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdRAT', precio=932.01, categorias=['Galletas'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdYUE', precio=152.47, categorias=['Gomas de mascar', 'Mashmelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdIIV', precio=355.76, categorias=['Gomas de mascar', 'Salados', 'Galletas'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdUTP', precio=176.78, categorias=['Galletas', 'Gomas de mascar', 'Salados'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdVJV', precio=832.69, categorias=['Mashmelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdQCK', precio=356.04, categorias=['Caramelos', 'Chocolates', 'Salados'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdGTC', precio=246.14, categorias=['Mashmelos', 'Galletas', 'Caramelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdNUU', precio=546.11, categorias=['Salados'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdUDQ', precio=889.15, categorias=['Gomas de mascar', 'Galletas', 'Mashmelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdTKN', precio=819.58, categorias=['Chocolates'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdMYP', precio=900.56, categorias=['Salados'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdEPB', precio=825.7, categorias=['Chocolates', 'Salados', 'Caramelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdRVO', precio=109.82, categorias=['Gomas de mascar', 'Caramelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdYHL', precio=771.88, categorias=['Gomas de mascar', 'Salados'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdVZS', precio=234.04, categorias=['Caramelos', 'Salados'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdPYU', precio=735.08, categorias=['Galletas', 'Mashmelos'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdTHC', precio=314.82, categorias=['Gomas de mascar', 'Chocolates'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdEFM', precio=224.33, categorias=['Galletas', 'Mashmelos', 'Salados'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdHEN', precio=276.21, categorias=['Galletas', 'Caramelos', 'Salados'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdFBR', precio=180.8, categorias=['Chocolates'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdBVW', precio=217.6, categorias=['Galletas'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdEUA', precio=588.53, categorias=['Caramelos', 'Salados', 'Gomas de mascar'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdTVD', precio=251.05, categorias=['Mashmelos', 'Caramelos', 'Gomas de mascar'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdJGX', precio=273.47, categorias=['Galletas', 'Salados'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdKGC', precio=792.28, categorias=['Gomas de mascar'], en_venta=True)
# ✅ Producto agregado: Producto(nombre='ProdMUB', precio=794.78, categorias=['Chocolates', 'Galletas'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdLHE', precio=544.4, categorias=['Salados', 'Chocolates'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdMWC', precio=800.22, categorias=['Galletas', 'Mashmelos'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdFBY', precio=803.91, categorias=['Galletas', 'Chocolates'], en_venta=False)
# ✅ Producto agregado: Producto(nombre='ProdNEC', precio=248.56, categorias=['Salados', 'Mashmelos'], en_venta=True)
#
# Ahora puede registrar manualmente:
